# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('wine quality.csv')

# %%
df.head(10)
# Out:
#    ixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.0             0.600         0.22             2.1      0.080
# 1           7.1             0.755         0.15             1.8      0.107
# 2           8.0             0.810         0.25             3.4      0.076
# 3           7.4             0.640         0.07             1.8      0.100
# 4           7.4             0.640         0.07             1.8      0.100
# 5           6.6             0.640         0.31             6.1      0.083
# 6           6.7             0.480         0.02             2.2      0.080
# 7           6.0             0.490         0.00             2.3      0.068
# 8           8.0             0.640         0.22             2.4      0.094
# 9           7.1             0.620         0.06             1.3      0.070
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   25                   105  0.99613  3.30       0.49
# 1                   20                    84  0.99593  3.19       0.50
# 2                   34                    85  0.99668  3.19       0.42
# 3                    8                    23  0.99610  3.30       0.58
# 4                    8                    23  0.99610  3.30       0.58
# 5                    7                    49  0.99718  3.35       0.68
# 6                   36                   111  0.99524  3.10       0.53
# 7                   15                    33  0.99292  3.58       0.59
# 8                    5                    33  0.99612  3.37       0.58
# 9                    5                    12  0.99420  3.17       0.48
#
#    alcohol  quality
# 0      9.9        5
# 1      9.5        5
# 2      9.2        5
# 3      9.6        5
# 4      9.6        5
# 5     10.3        5
# 6      9.7        5
# 7     12.5        6
# 8     11.0        5
# 9      9.8        5

# %%
df.tail(10)
# Out:
#      ixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 206           6.6             0.725         0.20             7.8      0.073
# 207           6.3             0.550         0.15             1.8      0.077
# 208           5.4             0.740         0.09             1.7      0.089
# 209           6.3             0.510         0.13             2.3      0.076
# 210           6.8             0.620         0.08             1.9      0.068
# 211           6.2             0.600         0.08             2.0      0.090
# 212           5.9             0.550         0.10             2.2      0.062
# 213           6.3             0.510         0.13             2.3      0.076
# 214           5.9             0.645         0.12             2.0      0.075
# 215           6.0             0.310         0.47             3.6      0.067
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 206                   29                    79  0.99770  3.29       0.54
# 207                   26                    35  0.99314  3.32       0.82
# 208                   16                    26  0.99402  3.67       0.56
# 209                   29                    40  0.99574  3.42       0.75
# 210                   28                    38  0.99651  3.42       0.82
# 211                   32                    44  0.99490  3.45       0.58
# 212                   39                    51  0.99512  3.52       0.76
# 213                   29                    40  0.99574  3.42       0.75
# 214                   32                    44  0.99547  3.57       0.71
# 215                   18                    42  0.99549  3.39       0.66
#
#      alcohol  quality
# 206      9.2        5
# 207     11.6        6
# 208     11.6        6
# 209     11.0        6
# 210      9.5        6
# 211     10.5        5
# 212     11.2        6
# 213     11.0        6
# 214     10.2        5
# 215     11.0        6

# %%
df.shape
# Out:
# (216, 12)

# %%
df.isnull().sum()
# Out:
# ixed acidity            0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        ixed acidity  volatile acidity  citric acid  residual sugar  \
# count    216.000000        216.000000   216.000000      216.000000
# mean       7.146296          0.546759     0.204861        2.577315
# std        1.049157          0.174492     0.174265        2.052626
# min        5.300000          0.160000     0.000000        1.300000
# 25%        6.400000          0.417500     0.060000        1.875000
# 50%        7.000000          0.555000     0.150000        2.100000
# 75%        7.600000          0.670000     0.330000        2.300000
# max       11.700000          1.040000     0.780000       15.400000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  216.000000           216.000000            216.000000  216.000000
# mean     0.076472            18.416667             43.745370    0.995936
# std      0.028922            11.418976             31.166693    0.001664
# min      0.038000             3.000000              8.000000    0.991820
# 25%      0.062750             9.000000             22.000000    0.995000
# 50%      0.072500            16.000000             32.000000    0.995830
# 75%      0.080000            26.000000             55.000000    0.996642
# max      0.235000            66.000000            147.000000    1.003690
#
#                pH   sulphates     alcohol     quality
# count  216.000000  216.000000  216.000000  216.000000
# mean     3.371667    0.655972   10.529552    5.574074
# std      0.129471    0.124904    0.924813    0.815018
# min      2.880000    0.420000    8.500000    3.000000
# 25%      3.290000    0.567500    9.800000    5.000000
# 50%      3.370000    0.640000   10.400000    6.000000
# 75%      3.442500    0.740000   11.125000    6.000000
# max      3.720000    1.100000   13.600000    8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ixed acidity          216 non-null    float64
#  1   volatile acidity      216 non-null    float64
#  2   citric acid           216 non-null    float64
#  3   residual sugar        216 non-null    float64
#  4   chlorides             216 non-null    float64
#  5   free sulfur dioxide   216 non-null    int64
#  6   total sulfur dioxide  216 non-null    int64
#  7   density               216 non-null    float64
#  8   pH                    216 non-null    float64
#  9   sulphates             216 non-null    float64
#  10  alcohol               216 non-null    float64
#  11  quality               216 non-null    int64
# dtypes: float64(9), int64(3)
# memory usage: 20.4 KB

# %%
df.groupby('quality').mean()
# Out:
#          ixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3            7.033333          0.871667     0.040000        3.200000
# 4            6.542857          0.706429     0.142857        2.257143
# 5            7.362105          0.571947     0.193263        2.493684
# 6            6.987500          0.535398     0.212386        2.804545
# 7            7.030000          0.401000     0.257000        2.105000
# 8            7.266667          0.356667     0.313333        1.833333
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.073667             9.666667             25.000000  0.997043
# 4         0.083714             8.714286             18.857143  0.996266
# 5         0.080958            19.189474             51.189474  0.996191
# 6         0.074614            18.840909             40.068182  0.995826
# 7         0.063150            18.600000             39.350000  0.995072
# 8         0.063667            11.666667             22.000000  0.994970
#
#                pH  sulphates    alcohol
# quality
# 3        3.420000   0.566667   9.950000
# 4        3.502857   0.587143  10.335714
# 5        3.345368   0.605579  10.115789
# 6        3.396250   0.687727  10.820076
# 7        3.356000   0.763500  11.315833
# 8        3.233333   0.853333  10.900000

# %%
corr = df.corr()
plt.figure(figsize=(12,7))
sns.heatmap(corr,cmap="coolwarm",annot=True)
plt.show()

# %%
plt.figure(figsize=[7,3])
# plot bar graph
plt.bar(df['quality'],df['alcohol'],color='orange')
# label x-axis
plt.xlabel('quality')
#label y-axis
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.pairplot(data=df,hue="quality")
plt.show()

# %%
df.corr()
# Out:
#                       ixed acidity  volatile acidity  citric acid  \
# ixed acidity              1.000000         -0.222474     0.499517
# volatile acidity         -0.222474          1.000000    -0.632951
# citric acid               0.499517         -0.632951     1.000000
# residual sugar            0.253747          0.025311     0.278351
# chlorides                 0.387779          0.035635     0.265120
# free sulfur dioxide       0.048814         -0.020620     0.022655
# total sulfur dioxide      0.146559          0.029414     0.125404
# density                   0.633237         -0.019494     0.358656
# pH                       -0.707068          0.232719    -0.382475
# sulphates                -0.000452         -0.478080     0.189738
# alcohol                  -0.340920         -0.187506     0.029282
# quality                  -0.068758         -0.379648     0.168561
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ixed acidity                0.253747   0.387779             0.048814
# volatile acidity            0.025311   0.035635            -0.020620
# citric acid                 0.278351   0.265120             0.022655
# residual sugar              1.000000   0.598700             0.376227
# chlorides                   0.598700   1.000000             0.343339
# free sulfur dioxide         0.376227   0.343339             1.000000
# total sulfur dioxide        0.272042   0.262129             0.694814
# density                     0.606555   0.569930             0.252935
# pH                         -0.186118  -0.318124            -0.181274
# sulphates                   0.038220  -0.012385             0.149528
# alcohol                    -0.205718  -0.336695            -0.225734
# quality                    -0.019704  -0.166840             0.052142
#
#                       total sulfur dioxide   density        pH  sulphates  \
# ixed acidity                      0.146559  0.633237 -0.707068  -0.000452
# volatile acidity                  0.029414 -0.019494  0.232719  -0.478080
# citric acid                       0.125404  0.358656 -0.382475   0.189738
# residual sugar                    0.272042  0.606555 -0.186118   0.038220
# chlorides                         0.262129  0.569930 -0.318124  -0.012385
# free sulfur dioxide               0.694814  0.252935 -0.181274   0.149528
# total sulfur dioxide              1.000000  0.194670 -0.346577  -0.102695
# density                           0.194670  1.000000 -0.315472   0.055433
# pH                               -0.346577 -0.315472  1.000000   0.053367
# sulphates                        -0.102695  0.055433  0.053367   1.000000
# alcohol                          -0.272643 -0.626760  0.367481   0.257432
# quality                          -0.074785 -0.212341 -0.040405   0.451847
#
#                        alcohol   quality
# ixed acidity         -0.340920 -0.068758
# volatile acidity     -0.187506 -0.379648
# citric acid           0.029282  0.168561
# residual sugar       -0.205718 -0.019704
# chlorides            -0.336695 -0.166840
# free sulfur dioxide  -0.225734  0.052142
# total sulfur dioxide -0.272643 -0.074785
# density              -0.626760 -0.212341
# pH                    0.367481 -0.040405
# sulphates             0.257432  0.451847
# alcohol               1.000000  0.402246
# quality               0.402246  1.000000

# %%
cormat=df.corr()
top_corr_features=cormat.index
plt.figure(figsize=(10,10))
sns.heatmap(df[top_corr_features].corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df.iloc[:,:-1].values
Y=df.iloc[:,-1].values

# %%
X
# Out:
# array([[ 8.   ,  0.6  ,  0.22 , ...,  3.3  ,  0.49 ,  9.9  ],
#        [ 7.1  ,  0.755,  0.15 , ...,  3.19 ,  0.5  ,  9.5  ],
#        [ 8.   ,  0.81 ,  0.25 , ...,  3.19 ,  0.42 ,  9.2  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
Y
# Out:
# array([5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 6, 5, 5, 6, 8, 6,
#        7, 6, 6, 7, 6, 6, 6, 6, 5, 5, 5, 5, 7, 5, 5, 5, 5, 6, 4, 6, 6, 6,
#        5, 5, 5, 5, 6, 6, 7, 6, 6, 5, 5, 5, 6, 7, 6, 5, 5, 6, 6, 5, 5, 5,
#        8, 7, 7, 7, 5, 6, 6, 6, 5, 5, 7, 6, 4, 6, 6, 5, 5, 7, 4, 7, 3, 5,
#        5, 6, 5, 5, 7, 5, 7, 3, 5, 4, 5, 4, 5, 4, 5, 5, 5, 5, 6, 6, 5, 5,
#        5, 7, 6, 5, 6, 6, 6, 5, 5, 5, 6, 6, 3, 6, 6, 6, 5, 6, 5, 6, 6, 6,
#        6, 5, 6, 5, 5, 6, 4, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 7, 6, 6,
#        6, 5, 5, 6, 7, 6, 6, 7, 6, 5, 5, 5, 8, 5, 5, 6, 5, 6, 7, 5, 6, 5,
#        5, 5, 5, 5, 5, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6,
#        5, 5, 5, 7, 6, 6, 6, 6, 5, 6, 6, 6, 6, 5, 6, 6, 5, 6], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
# array([[7.00000000e+00, 5.50000000e-01, 1.30000000e-01, ...,
#         3.36000000e+00, 5.90000000e-01, 9.70000000e+00],
#        [6.80000000e+00, 5.90000000e-01, 1.00000000e-01, ...,
#         3.41000000e+00, 6.70000000e-01, 9.70000000e+00],
#        [6.90000000e+00, 5.80000000e-01, 1.00000000e-02, ...,
#         3.40000000e+00, 7.30000000e-01, 9.70000000e+00],
#        ...,
#        [5.30000000e+00, 4.70000000e-01, 1.10000000e-01, ...,
#         3.54000000e+00, 8.80000000e-01, 1.35666667e+01],
#        [7.20000000e+00, 6.95000000e-01, 1.30000000e-01, ...,
#         3.29000000e+00, 5.40000000e-01, 1.01000000e+01],
#        [7.00000000e+00, 6.55000000e-01, 1.60000000e-01, ...,
#         3.37000000e+00, 5.50000000e-01, 9.70000000e+00]])

# %%
y_test
# Out:
# array([7, 6, 4, 5, 7, 7, 6, 6, 6, 5, 6, 5, 6, 5, 7, 5, 7, 5, 6, 8, 6, 5,
#        6, 7, 5, 6, 7, 6, 5, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 5, 5, 5,
#        4, 3, 6, 5, 3, 5, 6, 5, 6, 5, 6, 6, 6, 7, 4, 5, 7, 5, 5, 6, 5],
#       dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)
y_pred
# Out:
# array([6.62867898, 5.97514344, 4.51148938, 5.30170161, 5.06269669,
#        5.37218608, 6.10538108, 5.44419955, 6.86544428, 6.39451803,
#        5.7170194 , 6.14916715, 5.92413129, 5.31836801, 6.36848496,
#        5.30170161, 5.50844593, 5.16266859, 5.42076429, 6.4697685 ,
#        5.58651295, 5.44450375, 5.42421263, 7.23014078, 5.69177741,
#        5.34291572, 6.55559858, 5.81225075, 5.73693497, 5.42730422,
#        5.11889582, 5.12904483, 5.86620376, 6.30331307, 5.56259522,
#        5.33855835, 5.25679413, 5.49669925, 5.47984729, 5.5602049 ,
#        5.5602049 , 5.36535239, 5.12049062, 5.53243333, 5.45981675,
#        5.42704336, 5.95059136, 5.2125572 , 5.40293787, 5.4034815 ,
#        5.08282727, 4.99922931, 5.99076388, 5.04990951, 5.68471455,
#        6.85208014, 6.3738269 , 6.23539502, 4.77510571, 5.57208019,
#        6.02211159, 5.96527144, 5.13759788, 5.88355352, 5.62029951])

# %%
df=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
df
# Out:
#     Actual  Predicted
# 0        7   6.628679
# 1        6   5.975143
# 2        4   4.511489
# 3        5   5.301702
# 4        7   5.062697
# ..     ...        ...
# 60       7   6.022112
# 61       5   5.965271
# 62       5   5.137598
# 63       6   5.883554
# 64       5   5.620300
#
# [65 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
print("Mean Squared Error: ",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error:  0.6328802670247079
